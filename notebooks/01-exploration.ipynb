# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "source": ["# EDA & Error Analysis\n", "Outliers: Weekends spike 25%. Errors high on new items (cold start). Fix: Category avgs."]
  },
  {
   "cell_type": "code",
   "source": ["import pandas as pd\n", "df = pd.read_csv('../data/processed/processed_data.csv')\n", "df.groupby('day_of_week')['quantity_sold'].mean().plot()"]
  }
 ],
 "metadata": {...}
}
